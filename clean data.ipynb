# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os
from deep_translator import GoogleTranslator

# %%
df = pd.read_csv('TotalData1.csv')

# %%
df.duplicated()
#df.assign(is_duplicate=df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6037    False
# 6038    False
# 6039     True
# 6040    False
# 6041     True
# Length: 6042, dtype: bool

# %%
df.drop_duplicates(subset='rest name',keep='first', inplace=True)
df=df.sort_values("rest rank", ascending=False)
df.shape
# Out:
# (3724, 89)

# %%
df=df.fillna(0)

# %%
df
# Out:
#                                     rest name  \
# 3597                      הסביח של סומך, חדרה
# 1933               אושי אושי באר שבע, באר שבע
# 4010                     פיצה דומינו, תל אביב
# 711                      נפגש אצל אילן, טבריה
# 712                        אקסטרה פיצה, טבריה
# ...                                       ...
# 2786              שיפודים גריל ישראלי, אשקלון
# 2785                     פיצליאנו, מבשרת ציון
# 2783                    פיצריית מרילו, אחיעזר
# 2781  M Burger יבנה - M BURGER, מרכז מסחרי לב
# 6040                  אצל רחל בחצר, אלון מורה
#
#                               rest add rest open    rest type  rest rank  \
# 3597              הרברט סמואל 76, חדרה   No Info        חומוס        5.0
# 1933           שד' יצחק רגר 2, באר שבע   No Info   מצאת טעות?        5.0
# 4010                פרישמן 16, תל אביב   No Info       פיצריה        5.0
# 711        הירדן 12, טבריה, סובב כינרת   No Info    אוכל רחוב        5.0
# ...

# %%
# Load the CSV data
df = pd.read_csv('TotalData1.csv')

# Access a specific column by its name
column_data = df['rest type']

for i,col in enumerate(column_data):
    translated = GoogleTranslator(source='auto', target='en').translate(col)
    col=translated
    df.loc[i,'rest type']=translated
    print(df.loc[i,'rest type'])
# Out:
# Hummus
# Sushi
# A pizzeria
# Street food
# A pizzeria
# Home kitchen
# A pizzeria
# A pizzeria
# Confectionery-Mafia
# a dairy restaurant
# A steakhouse
# Oriental restaurant
# Oriental restaurant
# Hummus
# A pizzeria
# Confectionery-Mafia
# Asian restaurant
# Vegetarian restaurant
# A steakhouse
# sandwich bar
# Catering
# Hummus
# A pizzeria
# A steakhouse
# A pizzeria
# Street food
# A steakhouse
# Street food
# coffee shop
# Confectionery-Mafia
# Hummus
# Street food
# coffee shop
# Hummus
# A pizzeria
# Catering
# Hummus
# A pizzeria
# Hamburger restaurant
# A pizzeria
# a dairy restaurant
# Salad bar
# A steakhouse
# coffee shop
# coffee shop
# Street food
# coffee shop
# Hamburger restaurant
# A steakhouse
# Hummus
# Vegetarian restaurant
# Asian restaurant
# Street food
# A pizzeria
# coffee shop
# Confectionery-Mafia
# schnitzel
# Mediterranean restaurant
# Oriental restaurant
# Mediterranean restaurant
# A pizzeria
# A pizzeria
# A steakhouse
# Mexican restaurant
# ...

# %%
df.to_csv('TotalData1.csv',encoding='utf-8-sig',index=False)
