# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os
from deep_translator import GoogleTranslator

# %%
df = pd.read_csv('TotalData1.csv')

# %%
df.duplicated()

# מנקה רשומות כפולות
df.drop_duplicates(subset='rest name',keep='first', inplace=True)
df=df.sort_values("rest rank", ascending=False)
df.shape

# ממלא 0 במקומות ריקים בהם לא נמשך מידע כי לא קיים באתר
df=df.fillna(0)

df
# Out:
#                                               rest name
# 0                                   הסביח של סומך, חדרה  \
# 318                          שניצל ביסטרו בר, אור יהודה
# 316          בויה נקניק מגולגל בטוסט - בית שאן, בית שאן
# 315                                פיצה דומינו, תל אביב
# 314                                נפגש אצל אילן, טבריה
# ...                                                 ...
# 2289                               פיצליאנו, מבשרת ציון
# 2288                              פיצריית מרילו, אחיעזר
# 2287            M Burger יבנה - M BURGER, מרכז מסחרי לב
# 2286  פרש דה מרקט - Fresh The Market, מתחם ביג, קריי...
# 3723                            אצל רחל בחצר, אלון מורה
#
#                               rest add rest open           rest type
# 0                 הרברט סמואל 76, חדרה   No Info              Hummus  \
# 318         אליהו סעדון 124, אור יהודה   No Info           schnitzel
# 316      אהבת ישראל 9, בית שאן, העמקים   No Info         Street food
# ...

# %%
df.to_csv('TotalData1.csv',encoding='utf-8-sig',index=False)
